# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pyunitwizard as puw

# %%
puw.configure.load_library(['pint', 'simtk.unit'])

# %%
puw.convert('1 meter')
# Out:
# string None None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# string pint None
# ...

# %%
puw.get_form('1 meter')
# Out:
# 'string'
